# %%
import numpy as np

# %%
lon =12.1878; lat =48.1195; ele =487.9; Go =980717.39

# %%
Ge = 978031.85

# %%
np.pi
# Out:
# 3.141592653589793

# %%
print(np.sin(0))
# Out:
# 0.0

# %%
lat_r=lat*np.pi/180

# %%
np.sin(lat_r)
# Out:
# np.float64(0.7445387927201025)

# %%
Gt = Ge*(1+0.005278895*np.sin(lat_r)**2+0.000023462*np.sin(lat_r)**4)

# %%
FAC = ele*0.308

# %%
BC = ele*0.112

# %%
(Go + FAC) - Gt
# Out:
# np.float64(-33.24501448520459)

# %%
Go+FAC-BC-Gt
# Out:
# np.float64(-87.88981448521372)

# %%
sea_ele = -487.9

# %%
sea_FAC= sea_ele*0.308

# %%
sea_BC=0.112*sea_ele

# %%
Go+sea_FAC-Gt
# Out:
# np.float64(-333.791414485313)

# %%
Go+sea_FAC+sea_BC-Gt
# Out:
# np.float64(-388.4362144853221)
